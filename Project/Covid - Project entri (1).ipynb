# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\DELL\Desktop\Entri\Project/country_wise_latest.csv")

# %%
df
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
df.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
df.describe()
# Out:
#           Confirmed         Deaths     Recovered        Active     New cases  \
# count  1.870000e+02     187.000000  1.870000e+02  1.870000e+02    187.000000
# mean   8.813094e+04    3497.518717  5.063148e+04  3.400194e+04   1222.957219
# std    3.833187e+05   14100.002482  1.901882e+05  2.133262e+05   5710.374790
# min    1.000000e+01       0.000000  0.000000e+00  0.000000e+00      0.000000
# 25%    1.114000e+03      18.500000  6.265000e+02  1.415000e+02      4.000000
# 50%    5.059000e+03     108.000000  2.815000e+03  1.600000e+03     49.000000
# 75%    4.046050e+04     734.000000  2.260600e+04  9.149000e+03    419.500000
# max    4.290259e+06  148011.000000  1.846641e+06  2.816444e+06  56336.000000
#
#         New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# count   187.000000     187.000000          187.000000             187.000000
# mean     28.957219     933.812834            3.019519              64.820535
# ...

# %%
df.sort_values(by='Confirmed', ascending=False).head(10)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 79            India    1480073   33408     951166   495499      44457
# 138          Russia     816680   13334     602249   201097       5607
# 154    South Africa     452529    7067     274925   170537       7096
# 111          Mexico     395489   44022     303810    47657       4973
# 132            Peru     389717   18418     272547    98752      13756
# 35            Chile     347923    9187     319954    18782       2133
# 177  United Kingdom     301708   45844       1437   254427        688
# 81             Iran     293606   15912     255144    22550       2434
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %%
df.sort_values(by='Deaths', ascending=False).head(10)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 177  United Kingdom     301708   45844       1437   254427        688
# 111          Mexico     395489   44022     303810    47657       4973
# 85            Italy     246286   35112     198593    12581        168
# 79            India    1480073   33408     951166   495499      44457
# 61           France     220352   30212      81212   108928       2551
# 157           Spain     272421   28432     150376    93613          0
# 132            Peru     389717   18418     272547    98752      13756
# 81             Iran     293606   15912     255144    22550       2434
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %%
df.sort_values(by='Recovered', ascending=False).head(10)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 23          Brazil    2442375   87618    1846641   508116      23284
# 173             US    4290259  148011    1325804  2816444      56336
# 79           India    1480073   33408     951166   495499      44457
# 138         Russia     816680   13334     602249   201097       5607
# 35           Chile     347923    9187     319954    18782       2133
# 111         Mexico     395489   44022     303810    47657       4973
# 154   South Africa     452529    7067     274925   170537       7096
# 132           Peru     389717   18418     272547    98752      13756
# 81            Iran     293606   15912     255144    22550       2434
# 128       Pakistan     274289    5842     241026    27421       1176
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23          614          33728                3.59                  75.61
# ...

# %%
df.sort_values(by='Active', ascending=False).head(10)
# Out:
#      Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173              US    4290259  148011    1325804  2816444      56336
# 23           Brazil    2442375   87618    1846641   508116      23284
# 79            India    1480073   33408     951166   495499      44457
# 177  United Kingdom     301708   45844       1437   254427        688
# 138          Russia     816680   13334     602249   201097       5607
# 154    South Africa     452529    7067     274925   170537       7096
# 37         Colombia     257101    8777     131161   117163      16306
# 61           France     220352   30212      81212   108928       2551
# 32           Canada     116458    8944          0   107514        682
# 132            Peru     389717   18418     272547    98752      13756
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %%
df.sort_values(by='New cases', ascending=False).head(10)
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 173             US    4290259  148011    1325804  2816444      56336
# 79           India    1480073   33408     951166   495499      44457
# 23          Brazil    2442375   87618    1846641   508116      23284
# 37        Colombia     257101    8777     131161   117163      16306
# 132           Peru     389717   18418     272547    98752      13756
# 154   South Africa     452529    7067     274925   170537       7096
# 138         Russia     816680   13334     602249   201097       5607
# 111         Mexico     395489   44022     303810    47657       4973
# 6        Argentina     167416    3059      72575    91782       4890
# 13      Bangladesh     226225    2965     125683    97577       2772
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 173        1076          27941                3.45                  30.90
# ...

# %%
US_info1= [4290259, 148011, 1325804, 2816444]
labels = ["Confirmed", "Deaths", "Recovered", "Active"]
plt.xticks(range(len(US_info1)), labels)
plt.xlabel('labels')
plt.ylabel('values')
plt.title('Covid-19 in US')
plt.bar(range(len(US_info1)), US_info1, color="#003f5c")
# Out:
# <BarContainer object of 4 artists>

# %%
Brazil_info1= [2442375, 87618, 1846641, 508116]
labels = ["Confirmed", "Deaths", "Recovered", "Active"]
plt.xticks(range(len(Brazil_info1)), labels)
plt.xlabel('labels')
plt.ylabel('values')
plt.title('Covid-19 in Brazil')
plt.bar(range(len(Brazil_info1)), Brazil_info1, color="#2d578b")
# Out:
# <BarContainer object of 4 artists>

# %%
India_info1= [1480073,33408,951166,495499]
labels = ["Confirmed", "Deaths", "Recovered", "Active"]
plt.xticks(range(len(India_info1)), labels)
plt.xlabel('labels')
plt.ylabel('values')
plt.title('Covid-19 in India')
plt.bar(range(len(India_info1)), India_info1, color="#1f4472")
# Out:
# <BarContainer object of 4 artists>

# %%
Confirmed_info1= [4290259,1480073,2442375]
labels = ["US", "India", "Brazil"]
plt.xticks(range(len(Confirmed_info1)), labels)
plt.xlabel('labels')
plt.ylabel('values')
plt.title('Covid-19 - Confirmed')
plt.bar(range(len(Confirmed_info1)), Confirmed_info1, color="#bc5090")
# Out:
# <BarContainer object of 3 artists>

# %%
Deaths_info1= [148011,33408,87618]
labels = ["US", "India", "Brazil"]
plt.xticks(range(len(Deaths_info1)), labels)
plt.xlabel('labels')
plt.ylabel('values')
plt.title('Covid-19 - Deaths')
plt.bar(range(len(Confirmed_info1)), Deaths_info1, color="#ffa600")
# Out:
# <BarContainer object of 3 artists>
